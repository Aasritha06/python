# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
cars = pd.read_csv(r"C:\Users\Dakshith\Documents\Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
cars.shape
# Out:
# (81, 5)

# %% [raw]
#  EDA

# %% [raw]
# distplot
# box plot
# scatterplot

# %%
from seaborn import scatterplot

# %%
scatterplot(x=cars['VOL'],y=cars['MPG'])
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(x=cars)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.boxplot(x=cars['MPG'])
plt.show()

# %%
sns.distplot(x=cars['WT'])
plt.title('Distributionof weight of vehicles in thousand pounds')
plt.xlabel('weight in Thousand pounds')
plt.show()

# %%
sns.boxplot(x=cars['HP'])
plt.show()

# %%
sns.boxplot(x=cars['VOL'])
plt.show()

# %%
sns.boxplot(x=cars['SP'])
plt.show()

# %%
sns.boxplot(x=cars['WT'])
plt.show()

# %%
from seaborn import scatterplot

# %%
sns.distplot(x=cars['WT'])
# Out:
# <Axes: ylabel='Density'>

# %%
scatterplot(x=cars['HP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %%
scatterplot(x=cars['VOL'],y=cars['MPG'])
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
scatterplot(x=cars['HP'],y=cars['VOL'])
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
sns.scatterplot(x=cars['MPG'],color=['red'],y=cars['VOL'])
# Out:
# <Axes: xlabel='MPG', ylabel='VOL'>

# %%
scatterplot(x=cars['SP'],color=['purple'],y=cars['MPG'])
# Out:
# <Axes: xlabel='SP', ylabel='MPG'>

# %%
sns.barplot(x=cars['HP'],y=cars['WT'])
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
sns.barplot(x=cars['WT'],y=cars['SP'])
# Out:
# <Axes: xlabel='WT', ylabel='SP'>

# %%
sns.barplot(x=cars['WT'],y=cars['VOL'])
# Out:
# <Axes: xlabel='WT', ylabel='VOL'>

# %%
sns.barplot(x=cars['HP'],y=cars['SP'])
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
sns.barplot(x=cars['WT'],y=cars['VOL'])
# Out:
# <Axes: xlabel='WT', ylabel='VOL'>

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
cars[['HP','WT','VOL','SP']]=sc.fit_transform(cars[['HP','WT','VOL','SP']])

# %%
np.round(cars.describe(),2)
# Out:
#           HP    MPG    VOL     SP     WT
# count  81.00  81.00  81.00  81.00  81.00
# mean   -0.00  34.42   0.00   0.00   0.00
# std     1.01   9.13   1.01   1.01   1.01
# min    -1.21  12.10  -2.20  -1.56  -2.24
# 25%    -0.59  27.86  -0.44  -0.55  -0.38
# 50%    -0.31  35.15   0.10  -0.24   0.04
# 75%     0.40  39.53   0.64   0.35   0.67
# max     3.60  53.70   2.76   3.41   2.76

# %%
np.round(cars.describe(),4)
# Out:
#             HP      MPG      VOL       SP       WT
# count  81.0000  81.0000  81.0000  81.0000  81.0000
# mean   -0.0000  34.4221   0.0000   0.0000   0.0000
# std     1.0062   9.1314   1.0062   1.0062   1.0062
# min    -1.2063  12.1013  -2.2003  -1.5592  -2.2427
# 25%    -0.5897  27.8563  -0.4406  -0.5471  -0.3788
# 50%    -0.3078  35.1527   0.1008  -0.2364   0.0432
# 75%     0.3970  39.5316   0.6423   0.3451   0.6688
# max     3.6034  53.7007   2.7629   3.4099   2.7644

# %%
import statsmodels.formula.api as sm 
ml_v=smf.ols('MPG~VOL',data = cars).fit()
ml_v.rsquared
# Out:
# 0.2799008651122705

# %%
ml_v.params
# Out:
# Intercept    34.422076
# VOL          -4.801137
# dtype: float64

# %%
ml_w=smf.ols('MPG~VOL',data = cars).fit()
np.round(ml_w.rsquared,5)
# Out:
# 0.2799

# %%
ml_w.params
# Out:
# Intercept    34.422076
# VOL          -4.801137
# dtype: float64

# %%
ml_w=smf.ols('MPG~WT',data = cars).fit()
np.round(ml_w.rsquared,5)
# Out:
# 0.27748

# %%
ml_sp=smf.ols('MPG~WT',data = cars).fit()
ml_s.rsquared
# Out:
# 0.2774751389270127

# %%
ml_hp=smf.ols('MPG~VOL',data = cars).fit()
ml_hp.rsquared
# Out:
# 0.2799008651122705

# %%
ml_hp=smf.ols('MPG~VOL+WT+SP',data = cars).fit()
ml_hp.rsquared
# Out:
# 0.6876760478006351

# %%
import statsmodels.formula.api as sm 
model=smf.ols('MPG~VOL',data = cars).fit()

# %%
model.params
# Out:
# Intercept    34.422076
# VOL          -4.801137
# dtype: float64

# %%
model.rsquared
# Out:
# 0.2799008651122705
